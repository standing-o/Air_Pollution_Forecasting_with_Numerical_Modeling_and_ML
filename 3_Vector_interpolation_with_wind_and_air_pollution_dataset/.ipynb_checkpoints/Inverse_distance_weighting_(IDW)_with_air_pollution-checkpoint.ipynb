# %% [markdown]
# # Inverse distance weighting (IDW)
# - One of Geographic information system interpolation
# - Goal : (latitude, longitude, air pollution <- interpolation!)

# %% [markdown]
# ## 1. Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import idw
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import os

# %% [markdown]
# ## 2. Ground Truth

# %%
dataset = pd.read_csv("air_pollution_new/Hour_1.csv", header = None)
data = dataset.values[:,:]

latitude = data[:,1]
longitude = data[:,2]
z = data[:,3]

# %%
coo = []

for i in range(len(z)):
    coo.append([latitude[i], longitude[i]])

# %%
zz = []
for i in range(len(z)):
    zz.append([z[i]])

# %%
coo = np.array(coo)
zz = np.array(zz)
coo1 = np.array(coo[:,0])
coo2 = np.array(coo[:,1])

# %%
print(coo.shape)
print(coo1.shape)
print(coo2.shape)
print(zz.shape)
# Out:
# (314, 2)
# (314,)
# (314,)
# (314, 1)

# %%
# create sample points with structured scores
X1 = coo
z1 = zz

# %%
print("Shape :", X1.shape)
print("MAX :", np.max(X1))
print("MIN :", np.min(X1))
# Out:
# Shape : (314, 2)
# MAX : 1271.7
# MIN : 33.256

# %% [markdown]
# ## 3. Train and Test

# %%
idw_tree = idw.tree(X1, z1)

# %%
new_lat = np.arange(34, 37.51, 0.0351)
new_lon = np.arange(126, 130.001, 0.0403)

print(new_lat.shape)
print(new_lon.shape)
# Out:
# (100,)
# (100,)

# %%
X2 = np.meshgrid(new_lat, new_lon)
np.shape(X2)
# Out:
# (2, 100, 100)

# %%
grid_shape = X2[0].shape

# %%
X2 = np.reshape(X2, (2, -1)).T
X2.shape
# Out:
# (10000, 2)

# %%
z2 = idw_tree(X2)

# %%
print(X2.shape)
print(z2.shape)
# Out:
# (10000, 2)
# (10000,)

# %% [markdown]
# ## 4. Results

# %%
plt.rcParams["figure.figsize"] = (12,12)
fig = plt.figure()
ax1 = fig.gca(projection = '3d')
ax1.scatter(coo2,coo1, z1)
ax1.axis([126, 130, 34, 38])

plt.title("Air pollution data Ground Truth", fontsize=20)
plt.savefig("fig4.jpg")
plt.show()

# %%
X21, X22 = np.meshgrid(new_lat, new_lon)

plt.rcParams["figure.figsize"] = (12,12)
fig = plt.figure()
ax3 = fig.gca(projection = '3d')
ax3.plot_surface(X22, X21 , z2.reshape(grid_shape))

plt.title("Air pollution data after IDW Reconstruction", fontsize=20)
plt.savefig("fig5.jpg")
plt.show()

# %% [markdown]
# ## 5. Make Dataset

# %%
print(X21.shape)
print(X22.shape)
print(z2.reshape(grid_shape).shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %%
np.savetxt('Interpolation_air_pollution/Hour1_inter_lat.txt', X21)
np.savetxt('Interpolation_air_pollution/Hour1_inter_lon.txt', X22)
np.savetxt('Interpolation_air_pollution/Hour1_inter_p.txt', z2.reshape(grid_shape))

# %% [markdown]
# ## 6. Save for 24 hours

# %%
for hour in range(24) :
    path = os.path.join(os.getcwd(), 'air_pollution_new', 'Hour_{}'.format(hour+1) + '.csv')
    dataset = pd.read_csv(path, encoding = 'cp949', header = None)
    data = dataset.values[:,:]

    latitude = data[:,1]
    longitude = data[:,2]
    z = data[:,3]
    
    coo = []

    for i in range(len(z)):
        coo.append([latitude[i], longitude[i]])
        
    zz = []
    for i in range(len(z)):
        zz.append([z[i]])
    
    coo = np.array(coo)
    zz = np.array(zz)
    coo1 = np.array(coo[:,0])
    coo2 = np.array(coo[:,1])
    
    X1 = coo
    z1 = zz
    
    idw_tree = idw.tree(X1, z1)
    
#     new_lat = np.arange(34, 37.51, 0.0351)
#     new_lon = np.arange(126, 130.001, 0.0403)  

    new_lat = np.linspace(126, 129.5, 100)
    new_lon = np.linspace(34, 37.5, 100)
    
    X21, X22 = np.meshgrid(new_lat, new_lon)
    
    X2 = np.meshgrid(new_lat, new_lon)
    grid_shape = X2[0].shape
    X2 = np.reshape(X2, (2, -1)).T
    z2 = idw_tree(X2)
    
    print(z2)
    np.savetxt('Interpolation_air_pollution/' + 'Hour_{}'.format(hour+1) + '_inter_lat.txt', X21)
    np.savetxt('Interpolation_air_pollution/' + 'Hour_{}'.format(hour+1) + '_inter_lon.txt', X22)
    np.savetxt('Interpolation_air_pollution/' + 'Hour_{}'.format(hour+1) + '_inter_p.txt', z2.reshape(grid_shape))
# Out:
# [25.99911801 25.99911854 25.99911907 ... 25.16625583 25.16625609
#  25.16625634]
# [29.33183983 29.33184065 29.33184148 ... 27.33280649 27.33280509
#  27.33280369]
# [30.83373188 30.83373211 30.83373235 ... 29.00124098 29.00123905
#  29.00123713]
# [30.50119495 30.50119479 30.50119463 ... 29.33504568 29.33504423
#  29.33504279]
# [32.83431643 32.83431624 32.83431604 ... 32.33453046 32.33452969
#  32.33452893]
# [38.33210603 38.33210562 38.3321052  ... 37.66567183 37.66567182
#  37.66567181]
# [48.33222957 48.3322292  48.33222884 ... 48.83193331 48.831934
#  48.8319347 ]
# [57.66855459 57.66855394 57.66855329 ... 57.00215209 57.0021512
#  57.00215032]
# [68.83403365 68.83403375 68.83403385 ... 65.83531226 65.83530809
#  65.83530392]
# [69.00141659 69.00141715 69.00141771 ... 69.83449233 69.83449282
#  69.83449332]
# [87.83437946 87.83438089 87.83438233 ... 92.66587704 92.66588265
#  92.66588826]
# [126.50683488 126.50683741 126.50683995 ... 134.5037506  134.50375581
#  134.50376101]
# [155.66848665 155.66848689 155.66848713 ... 160.8327269  160.83272794
#  160.83272898]
# [180.82837579 180.82837149 180.82836719 ... 177.66197858 177.66196982
#  177.66196107]
# [132.16694582 132.16693917 132.16693253 ... 126.50220415 126.50220334
#  126.50220253]
# [104.84682226 104.8468196  104.84681694 ... 108.17851636 108.17851435
#  108.17851233]
# [71.50318994 71.50318982 71.5031897  ... 78.16694639 78.16695154
#  78.16695669]
# [64.33391006 64.33391072 64.33391137 ... 71.83070021 71.83070718
#  71.83071415]
# [72.83486537 72.83486755 72.83486972 ... 81.66463137 81.66463949
#  81.6646476 ]
# [72.83634215 72.83634487 72.83634759 ... 81.99944191 81.99945064
#  81.99945936]
# [68.16922285 68.16922572 68.16922858 ... 76.33278531 76.3327934
#  76.33280149]
# [63.83547998 63.83548252 63.83548505 ... 69.33350213 69.33350782
#  69.33351351]
# [59.1683525  59.16835409 59.16835568 ... 63.83319292 63.83319668
#  63.83320044]
# [58.16810167 58.16810287 58.16810407 ... 61.9999112  61.99991412
#  61.99991702]

# %% [markdown]
# ### Reference
# - [1] [inverse_distance_weighting], https://github.com/paulbrodersen/inverse_distance_weighting/blob/master/LICENSE
